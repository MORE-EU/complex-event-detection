# %%
import os, sys
from tqdm import tqdm
import seaborn as sns
module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from modules.preprocessing import *
from modules.io import *
from modules.learning import *
from modules.patterns import *
from modules.statistics import *
from modules.plots import *
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from IPython.display import display
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import normalize
import seaborn
import pickle
from tqdm.notebook import tqdm
plt.style.use('ggplot')

# %% [markdown]
# # Detect with static yaw with a different approach (regression that fits best)

# %% [markdown]
# # Load Data

# %%
dataset_file = '/data/data2/engie_initial/post_treated_data/BEZ/BEBEZE03_scada_high_frequency.parquet'
df = load_df(dataset_file)
df = df.dropna(axis=1, how='all')
df.columns = df.columns.str.replace('cor. ', '', regex=False)

# %%
cols = ['wind speed', 'pitch angle', 'rotor speed', 'active power',
        'nacelle direction', 'wind direction']
df = df[cols]

# %% [markdown]
# # Resample and apply filters

# %%
df.head()
# Out:
#                      wind speed  pitch angle  rotor speed  active power  \
# datetime
# 2018-01-02 00:00:00   11.689011     4.920000    13.099948   1670.194214
# 2018-01-02 00:00:02   10.209633     3.107840    13.768863   1734.004761
# 2018-01-02 00:00:04    9.639848     2.857445    13.966517   1798.870400
# 2018-01-02 00:00:06    9.407192     2.607051    14.164171   1825.356445
# 2018-01-02 00:00:08    9.367785     2.356656    14.353823   1939.916748
#
#                      nacelle direction  wind direction
# datetime
# 2018-01-02 00:00:00         225.560364      219.963791
# 2018-01-02 00:00:02         225.560364      221.596112
# 2018-01-02 00:00:04         225.560364      226.059685
# 2018-01-02 00:00:06         225.560364      222.380832
# 2018-01-02 00:00:08         225.560364      215.048021

# %%
def outliers_IQR(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    df_iqr = df[~((df < (Q1 - 1.5 * IQR)) | (df >(Q3 + 1.5 * IQR))).any(axis=1)]
    return df_iqr

# Resample with 60second granularity
df=change_granularity(df,granularity='1min')

df["theta_d"] = (df['wind direction'] - df['nacelle direction']) % 360
df["theta_d"][df["theta_d"] > +180] -= 360
df["theta_d"][df["theta_d"] < -180] += 360
df["theta_d"] = df["theta_d"].rolling(60).mean()
df = df.dropna()

df_initial = df.copy()

# Perform IQR outlier removal
df = outliers_IQR(df)
print(df.shape)

# drop values of wind speed under 5m/s
df=filter_col(df, 0, less_than=5, bigger_than=11)

# drop values with pitch angle higher than 2 degrees or lower than -2 degrees
df=filter_col(df, 1, less_than=-2, bigger_than=2)

# drop values of rotor speed under 8rpm
df=filter_col(df, 2, less_than=8, bigger_than=15)

# drop values of power near the power_limit and near or below zero
power_limit = 2050
df=filter_col(df, 4, less_than=1e-4, bigger_than= None)



#filter dynamic yaw
#df=filter_col(df, -1, less_than=-1, bigger_than= 1)

# Keep only dates with lidar measurements
start = '2018-06-02'
end = '2019-01-11'
df = filter_dates(df, start, end)
print(df.info())
# Out:
# Resample Complete
# Groupping Complete
# Chunk Interpolate Done
# Interpolate Complete
# (498351, 7)
# Filter Complete
# Filter Complete
# Filter Complete
# Filter Complete
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 136192 entries, 2018-06-02 00:00:00 to 2019-01-10 23:45:00
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   wind speed         136192 non-null  float64
#  1   pitch angle        136192 non-null  float64
#  2   rotor speed        136192 non-null  float64
#  3   active power       136192 non-null  float64
#  4   nacelle direction  136192 non-null  float64
#  5   wind direction     136192 non-null  float64
#  6   theta_d            136192 non-null  float64
# dtypes: float64(7)
# memory usage: 8.3 MB
# None

# %%
ax1=df_initial.plot.scatter(x='wind speed', y='active power', figsize=(12, 10), label='Before filtering')
df.plot.scatter(ax=ax1, x='wind speed', y='active power', c='orange', label = 'After filtering and IQR')
plt.title("Data before and after filtering")
plt.show()

# %% [markdown]
# # Print statistics

# %%
df.describe()
# Out:
#           wind speed    pitch angle    rotor speed   active power  \
# count  136192.000000  136192.000000  136192.000000  136192.000000
# mean        6.745582       0.115850      11.500082     636.510784
# std         1.262823       0.293845       1.512116     368.726568
# min         5.000024       0.000000       8.112732      -9.336444
# 25%         5.734942       0.000000      10.456061     345.856172
# 50%         6.498056       0.000000      11.634141     545.085348
# 75%         7.514249       0.000000      12.171931     854.621911
# max        10.997084       1.999871      14.999933    1976.667560
#
#        nacelle direction  wind direction        theta_d
# count      136192.000000   136192.000000  136192.000000
# mean          192.138946      191.704210      -0.508339
# std            89.437401       86.059437       5.738693
# min             0.519865        1.220752     -18.012062
# 25%           137.823743      135.960048      -3.584244
# 50%           188.243683      189.465970      -0.231389
# 75%           254.097565      246.085835       2.880218
# max           359.498288      357.642532      16.937191

# %% [markdown]
# # Print correlations

# %%
df.corr()
# Out:
#                    wind speed  pitch angle  rotor speed  active power  \
# wind speed           1.000000     0.581065     0.760827      0.901873
# pitch angle          0.581065     1.000000     0.279682      0.643454
# rotor speed          0.760827     0.279682     1.000000      0.842910
# active power         0.901873     0.643454     0.842910      1.000000
# nacelle direction   -0.129175    -0.113414    -0.152793     -0.189744
# wind direction      -0.136687    -0.117088    -0.155248     -0.197258
# theta_d             -0.049703     0.007301     0.010000     -0.037224
#
#                    nacelle direction  wind direction   theta_d
# wind speed                 -0.129175       -0.136687 -0.049703
# pitch angle                -0.113414       -0.117088  0.007301
# rotor speed                -0.152793       -0.155248  0.010000
# active power               -0.189744       -0.197258 -0.037224
# nacelle direction           1.000000        0.940266 -0.204712
# wind direction              0.940266        1.000000 -0.151792
# theta_d                    -0.204712       -0.151792  1.000000

# %% [markdown]
# # Remove outliers using the iQR method and Local Outlier Factor

# %%
def outliers_LoF(df):
    clf = LocalOutlierFactor(n_neighbors=300, n_jobs=16)
    res = clf.fit_predict(df)
    df = df[res == 1]
    return df

# %%
df_outliers = df.copy()
df = outliers_LoF(df).copy()
print(df.shape)
# Out:
# (133339, 7)

# %%
# TODO filtering and iqr fix

# %%
ax1 = df_initial.plot.scatter(x='wind speed', y='active power', figsize=(14, 12), label='Before filtering')
ax1 = df_outliers.plot.scatter(ax =ax1, x='wind speed', y='active power', c='orange', figsize=(14, 12), label='After filteringand IQR- Before LoF outlier detection')
df.plot.scatter(ax=ax1, x='wind speed', y='active power', c='green', label = 'After outlier detection')
plt.show()

# %% [markdown]
# # Add a column with the measured static yaw misalignment

# %%
df["y"] = np.nan
m1 = (df.index >= '2018-10-17') & (df.index < '2018-10-24')
m2 = (df.index >= '2018-12-11')
date_masks = [(df.index < '2018-08-02'),
              (df.index >= '2018-08-02') & (df.index < '2018-10-04'),
              (df.index >= '2018-10-04') & (df.index < '2018-10-17'),
              (df.index >= '2018-10-17') & (df.index < '2018-10-24'),
              (df.index >= '2018-10-24') & (df.index < '2018-12-11'),
              (df.index >= '2018-12-11')]


#static_misalignment_values = [-6.7, 4.8, 9.4, 0, -5.8, 0] # BBZ1

#static_misalignment_values = [2.7, 2.7, 4.9, 0, -5.1, 0] # BBZ2

static_misalignment_values = [-2.2, 3.4, 7.5, 0, -5.5, 0] # BBZ3


for m, s in zip(date_masks, static_misalignment_values):
    df.loc[m, 'y'] = s
df['y'].plot()
plt.title("Measured yaw misalignment")
plt.show()

df['theta_d'].plot()
plt.title("Dynamic yaw misalignment (1 hour rolling mean)")
plt.show()

# %% [markdown]
# ### Split dataset into bins based on wind speed

# %%
bin_size = 0.5
min_speed = 5
max_speed = 11
bins = np.arange(min_speed, max_speed, bin_size)
bins = np.append(bins,max_speed)
print(bins)
bin_masks = []
bin_feature = 'wind speed'
for i in range(len(bins) - 1):
    mask = (df[bin_feature]>= bins[i]) & (df[bin_feature] < bins[i + 1])
    bin_masks.append(mask)
# Out:
# [ 5.   5.5  6.   6.5  7.   7.5  8.   8.5  9.   9.5 10.  10.5 11. ]

# %% [markdown]
# # Estimate the yaw angle using a weighted average of the predicted angles

# %%
n_most_freq = None # choose how many of the most frequent values will be used in the weighted average None -> use all values

# %% [markdown]
# ### Wind speed only

# %%
df_scaled = scale_df(df.copy())
df_scaled['y'] = df['y']
selected_features = ['wind speed', 'pitch angle', 'rotor speed']
models_file = 'trained_models_wind_speed.pickle' 
with open(models_file, 'rb') as file:
    models_dict = pickle.load(file)
    
bin_feature = 'wind speed'
binned_data_dfs = []
for b in bin_masks:
    df_temp = df_scaled[b]
    binned_data_dfs.append(df_temp.copy())
    
fit_features = selected_features 
fit_features = ['wind speed']
target_feature = ['active power']
    
evaluation_scores = {}
evaluation_preds = {}
static_misalignment_values1 = [x for i, x in enumerate(static_misalignment_values) if i != 4]
print(static_misalignment_values1)
for theta_s in tqdm(np.unique(static_misalignment_values1)):
    #print(f'Working on {theta_s}')
    evaluation_scores[str(theta_s)] = {}
    evaluation_preds[str(theta_s)] = {}
    for key, models in models_dict.items():
        mape_list = []
        evaluation_preds[str(theta_s)][key] = {}
        #print(f'evaluating with models trained on {key}')
        for bin_n, d in enumerate(binned_data_dfs):
            d = d[d['y'] == theta_s].copy()
            if d.shape[0] >= 100 and models[bin_n] is not None:
                test_preds = predict(d, models[bin_n], fit_features, target_feature)
                r_sq, mae, me, mape, mpe = score(d[target_feature].values, test_preds)
                mape_list.append(mae)
                evaluation_preds[str(theta_s)][key][str(bin_n)] = test_preds
            else:
                evaluation_preds[str(theta_s)][key][str(bin_n)] = None
        avg_mape = np.mean(mape_list)
        evaluation_scores[str(theta_s)][key] = avg_mape
print(evaluation_scores)

# estimate the angle using a weighted average with the frequency of each point
result = {}
for th_s in np.unique(static_misalignment_values1): 
    print(th_s)
    average_for_each_bin = []
    for bin_n, d in enumerate(binned_data_dfs):
        d = d[d['y'] == th_s].copy()
        if d.shape[0] <= 100 or test_preds is None:
            continue
            
        # label each point in one bin to the closest prediction by the models of each angle of the bin
        label_per_bin = np.zeros(d[target_feature].shape) - 1
        diffs_per_bin = np.zeros(d[target_feature].shape) + np.inf # used to hold the minimum diffs until now
        l_test = np.zeros(d[target_feature].shape) - 1
        scoring_metrics = {}
        test_diffs = []
        for key, bin_dict in evaluation_preds[str(th_s)].items():
            # these are the predictions if the trained model corresponding to "key" angle/ in bin bin_n
            test_preds = bin_dict[str(bin_n)]
            if d.shape[0] >= 100 and test_preds is not None:
                # calculate the differences between the actual and predicted values (residuals)
                (r_sq, mae, me, mape, mpe) = score(d[target_feature].values, test_preds)
                temp_diff = np.abs(test_preds-d[target_feature].values)
                test_diffs.append(temp_diff.ravel())
#                 # unncomment line below for histograms of the differences for each bin for each model
#                 plt.hist(temp_diff, label=key, bins = 20)
#                 plt.axvline(temp_diff.mean(), color='k', linestyle='dashed', linewidth=1, label=f'mean of {key} = {temp_diff.mean():.3}')
#                 plt.legend()
#                 plt.show()
                mask = (temp_diff <= diffs_per_bin) # mask to find the points with current difference lower than the minimum
                diffs_per_bin[mask] = temp_diff[mask]
                scoring_metrics[str(np.abs(float(key)))] = (r_sq, mae, me, mape, mpe) # store metrics 
                label_per_bin[mask] = np.abs(float(key)) # assign labels
            else:
                pass
        unique, counts = np.unique(label_per_bin, return_counts=True)
        print(f"For bin {bin_n} in the regions with ground truth angle {th_s}")
        print(f"The distribution of prediction labels for the interval is:")
        print(unique, counts, end='\n\n')
        # barplot  with the frequencies of each label
#         plt.bar(np.arange(unique.shape[0]), counts)
#         plt.xticks(np.arange(unique.shape[0]), labels=unique)
#         plt.show()
        # calculate weighted average for each bin
        if n_most_freq is not None:
            idx = counts.argsort()[::-1][:n_most_freq]
            unique = unique[idx]
            counts = counts[idx]
        res = np.average(unique, weights=counts)
        average_for_each_bin.append(res)
    print("The weighted average (by frequency) of this bin is:")
    print(average_for_each_bin)
    print(np.mean(average_for_each_bin))
    result[str(th_s)] = np.mean(average_for_each_bin)
    
df['y_pred'] = np.nan
for th_s in np.unique(static_misalignment_values1): 
    df['y_pred'][df['y']==th_s] = result[str(th_s)]

prediction = np.abs(df['y_pred'])
target = np.abs(df['y'])

rmse = np.sqrt(np.nanmean((prediction.values-target.values)**2))
mae = np.nanmean(np.abs(prediction.values-target.values))
m = (prediction.isna())
print(f"RMSE = {rmse}")
print(f"MAE = {mae}")

target.plot(figsize=(12, 8), label = 'Measured static yaw')
prediction.plot(alpha=0.5, label = 'Predicted static yaw')
plt.title('Wind speed only')
plt.legend()
plt.show()
# Out:
# [-2.2, 3.4, 7.5, 0, 0]
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'-2.2': {'-6.7': 0.0380236076366942, '0.0': 0.1498939686063887, '4.8': 0.03778615124623401, '9.4': 0.050202290974232434}, '0.0': {'-6.7': 0.14442286646579258, '0.0': 0.05580632144659734, '4.8': 0.16613857097184204, '9.4': 0.19789405720188719}, '3.4': {'-6.7': 0.04166506286939965, '0.0': 0.15217127562399685, '4.8': 0.048479881120640646, '9.4': 0.0541642082914627}, '7.5': {'-6.7': 0.050584947144124245, '0.0': 0.17814927700527106, '4.8': 0.04337692990236713, '9.4': 0.03964555448560039}}
# -2.2
# For bin 0 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 145 1733 2498 2957]
#
# For bin 1 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 120 1594 2449 2592]
#
# For bin 2 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 103 1361 2377 2215]
#
# For bin 3 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  88  971 1822 1795]
#
# For bin 4 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  92  701 1337 1338]
#
# For bin 5 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [143 533 666 998]
#
# For bin 6 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [151 300 411 586]
#
# For bin 7 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 65 161 345 291]
#
# For bin 8 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 14  86 211  68]
#
# For bin 9 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 1 43 83 12]
#
# The weighted average (by frequency) of this bin is:
# [7.207254875221602, 7.168660251665433, 7.146581902245706, 7.215825491873395, 7.179901960784314, 7.009316239316241, 6.700345303867405, 6.751392111368911, 6.505804749340369, 6.297122302158273]
# 6.918220518784165
# 0.0
# For bin 0 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [3243   69  210  118]
#
# For bin 1 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [2816   73  244  136]
#
# For bin 2 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [2598   34  164   50]
#
# For bin 3 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [2298   52  131   25]
#
# For bin 4 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1859   25   83   49]
#
# For bin 5 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1249    2   81    8]
#
# For bin 6 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7] [943   2  97]
#
# For bin 7 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [547   2 108   1]
#
# For bin 8 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7] [185   2  75]
#
# For bin 9 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7] [117   1  17]
#
# The weighted average (by frequency) of this bin is:
# [0.7822527472527473, 0.998348118690731, 0.6085734364019677, 0.5436153232242618, 0.5638392857142858, 0.46828358208955234, 0.6329174664107485, 1.1285714285714286, 1.9545801526717559, 0.8792592592592593]
# 0.8560240800286738
# 3.4
# For bin 0 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 253 1535 2793 3361]
#
# For bin 1 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 224 1610 2959 2872]
#
# For bin 2 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 227 1546 2716 2843]
#
# For bin 3 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 242 1050 2453 1985]
#
# For bin 4 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 234  777 1855 1587]
#
# For bin 5 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 277  728 1186 1165]
#
# For bin 6 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [188 519 735 958]
#
# For bin 7 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 83 256 563 541]
#
# For bin 8 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 25 226 399 267]
#
# For bin 9 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 32 212 232 144]
#
# For bin 10 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [205 204]
#
# For bin 11 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 67 501]
#
# The weighted average (by frequency) of this bin is:
# [7.261961722488039, 7.116777560339204, 7.13887070376432, 7.004205933682375, 6.9786436110487315, 6.672109654350416, 6.842041666666668, 6.98981288981289, 6.8352235550708835, 6.331612903225807, 7.09437652811736, 8.857394366197184]
# 7.093585924563656
# 7.5
# For bin 0 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  3 128 106 457]
#
# For bin 1 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  1 135 120 646]
#
# For bin 2 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 10 128 136 599]
#
# For bin 3 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 12 151 160 532]
#
# For bin 4 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 26 159 263 617]
#
# For bin 5 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 30 208 253 572]
#
# For bin 6 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 27 219 227 606]
#
# For bin 7 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  9 163 202 648]
#
# For bin 8 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  1 175 112 375]
#
# For bin 9 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  2 150  46  90]
#
# For bin 10 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 78 121]
#
# The weighted average (by frequency) of this bin is:
# [8.098559077809798, 8.34190687361419, 8.19725085910653, 7.950409356725147, 7.81699530516432, 7.592003762935089, 7.663113994439295, 8.049902152641879, 7.715535444947209, 6.507638888888889, 7.596984924623117]
# 7.775481876445042
# RMSE = 3.6140512353369565
# MAE = 3.2453618839845384

# %%
df_scaled = scale_df(df.copy())
df_scaled['y'] = df['y']
selected_features = ['wind speed', 'pitch angle', 'rotor speed']
models_file = 'trained_models_selected.pickle' 
with open(models_file, 'rb') as file:
    models_dict = pickle.load(file)
    
bin_feature = 'wind speed'
binned_data_dfs = []
for b in bin_masks:
    df_temp = df_scaled[b]
    binned_data_dfs.append(df_temp.copy())
    
fit_features = selected_features 
target_feature = ['active power']
    
evaluation_scores = {}
evaluation_preds = {}
static_misalignment_values1 = [x for i, x in enumerate(static_misalignment_values) if i != 4]
print(static_misalignment_values1)
for theta_s in tqdm(np.unique(static_misalignment_values1)):
    #print(f'Working on {theta_s}')
    evaluation_scores[str(theta_s)] = {}
    evaluation_preds[str(theta_s)] = {}
    for key, models in models_dict.items():
        mape_list = []
        evaluation_preds[str(theta_s)][key] = {}
        #print(f'evaluating with models trained on {key}')
        for bin_n, d in enumerate(binned_data_dfs):
            d = d[d['y'] == theta_s].copy()
            if d.shape[0] >= 100 and models[bin_n] is not None:
                test_preds = predict(d, models[bin_n], fit_features, target_feature)
                r_sq, mae, me, mape, mpe = score(d[target_feature].values, test_preds)
                mape_list.append(mae)
                evaluation_preds[str(theta_s)][key][str(bin_n)] = test_preds
            else:
                evaluation_preds[str(theta_s)][key][str(bin_n)] = None
        avg_mape = np.mean(mape_list)
        evaluation_scores[str(theta_s)][key] = avg_mape
print(evaluation_scores)

# estimate the angle using a weighted average with the frequency of each point
result = {}
for th_s in np.unique(static_misalignment_values1): 
    print(th_s)
    average_for_each_bin = []
    for bin_n, d in enumerate(binned_data_dfs):
        d = d[d['y'] == th_s].copy()
        if d.shape[0] <= 100 or test_preds is None:
            continue
            
        # label each point in one bin to the closest prediction by the models of each angle of the bin
        label_per_bin = np.zeros(d[target_feature].shape) - 1
        diffs_per_bin = np.zeros(d[target_feature].shape) + np.inf # used to hold the minimum diffs until now
        l_test = np.zeros(d[target_feature].shape) - 1
        scoring_metrics = {}
        test_diffs = []
        for key, bin_dict in evaluation_preds[str(th_s)].items():
            # these are the predictions if the trained model corresponding to "key" angle/ in bin bin_n
            test_preds = bin_dict[str(bin_n)]
            if d.shape[0] >= 100 and test_preds is not None:
                # calculate the differences between the actual and predicted values (residuals)
                (r_sq, mae, me, mape, mpe) = score(d[target_feature].values, test_preds)
                temp_diff = np.abs(test_preds-d[target_feature].values)
                test_diffs.append(temp_diff.ravel())
#                 # unncomment line below for histograms of the differences for each bin for each model
#                 plt.hist(temp_diff, label=key, bins = 20)
#                 plt.axvline(temp_diff.mean(), color='k', linestyle='dashed', linewidth=1, label=f'mean of {key} = {temp_diff.mean():.3}')
#                 plt.legend()
#                 plt.show()
                mask = (temp_diff <= diffs_per_bin) # mask to find the points with current difference lower than the minimum
                diffs_per_bin[mask] = temp_diff[mask]
                scoring_metrics[str(np.abs(float(key)))] = (r_sq, mae, me, mape, mpe) # store metrics 
                label_per_bin[mask] = np.abs(float(key)) # assign labels
            else:
                pass
        unique, counts = np.unique(label_per_bin, return_counts=True)
        print(f"For bin {bin_n} in the regions with ground truth angle {th_s}")
        print(f"The distribution of prediction labels for the interval is:")
        print(unique, counts, end='\n\n')
        # barplot  with the frequencies of each label
#         plt.bar(np.arange(unique.shape[0]), counts)
#         plt.xticks(np.arange(unique.shape[0]), labels=unique)
#         plt.show()
        # calculate weighted average for each bin
        if n_most_freq is not None:
            idx = np.argmax(counts)
            unique = unique[idx]
            counts = counts[idx]
        res = np.average(unique, weights=counts)
        average_for_each_bin.append(res)
    print("The weighted average (by frequency) of this bin is:")
    print(average_for_each_bin)
    print(np.mean(average_for_each_bin))
    result[str(th_s)] = np.mean(average_for_each_bin)
    
df['y_pred'] = np.nan
for th_s in np.unique(static_misalignment_values1): 
    df['y_pred'][df['y']==th_s] = result[str(th_s)]
    
prediction = np.abs(df['y_pred'])
target = np.abs(df['y'])

rmse = np.sqrt(np.nanmean((prediction.values-target.values)**2))
mae = np.nanmean(np.abs(prediction.values-target.values))
m = (prediction.isna())
print(f"RMSE = {rmse}")
print(f"MAE = {mae}")

target.plot(figsize=(12, 8), label = 'Measured static yaw')
prediction.plot(alpha=0.5, label = 'Predicted static yaw')
plt.title('Selected features')
plt.legend()
plt.show()
# Out:
# [-2.2, 3.4, 7.5, 0, 0]
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'-2.2': {'-6.7': 0.034177498527035374, '0.0': 0.06391263293748912, '4.8': 0.034691011168607976, '9.4': 0.03414612060359487}, '0.0': {'-6.7': 0.07149343588784793, '0.0': 0.04693052642434775, '4.8': 0.06714301839533228, '9.4': 0.07832773903850929}, '3.4': {'-6.7': 0.037339463501536996, '0.0': 0.06241575116858759, '4.8': 0.04375448361416386, '9.4': 0.03974965967489868}, '7.5': {'-6.7': 0.041834694811153386, '0.0': 0.0679123634963648, '4.8': 0.04306247810257296, '9.4': 0.04072636676033724}}
# -2.2
# For bin 0 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 923  537 3832 2041]
#
# For bin 1 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 252  690  710 5103]
#
# For bin 2 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  57 1095  234 4670]
#
# For bin 3 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 729  381  585 2981]
#
# For bin 4 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1233  404  579 1252]
#
# For bin 5 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 665  165  436 1074]
#
# For bin 6 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [182 228 340 698]
#
# For bin 7 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 52 101 148 561]
#
# For bin 8 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 26  41 115 197]
#
# For bin 9 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [38 21 57 23]
#
# The weighted average (by frequency) of this bin is:
# [6.469030410473204, 8.295662472242784, 8.375462351387055, 7.2219204448246375, 5.071309111880047, 5.901196581196582, 6.860220994475137, 7.8303944315545255, 7.4382585751978905, 5.0280575539568355]
# 6.8491512927188705
# 0.0
# For bin 0 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1595 1053  607  385]
#
# For bin 1 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1465  389  331 1084]
#
# For bin 2 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1851  231  390  374]
#
# For bin 3 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1491  249  346  420]
#
# For bin 4 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1088  248  611   69]
#
# For bin 5 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [394 392 161 393]
#
# For bin 6 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [255 258 245 284]
#
# For bin 7 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [290 130  62 176]
#
# For bin 8 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [69 64 56 73]
#
# For bin 9 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [63 28 14 30]
#
# The weighted average (by frequency) of this bin is:
# [3.5000824175824174, 4.366625879473845, 2.5430077301475755, 2.977414205905826, 2.94280753968254, 4.966044776119403, 5.325815738963532, 4.093920972644377, 5.2236641221374045, 3.779259259259259]
# 3.9718642641916175
# 3.4
# For bin 0 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1120  834 3707 2281]
#
# For bin 1 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 248  845  944 5628]
#
# For bin 2 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 111 1153  303 5765]
#
# For bin 3 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1136  509  781 3304]
#
# For bin 4 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1711  508  657 1577]
#
# For bin 5 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1026  199  578 1553]
#
# For bin 6 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 383  317  630 1070]
#
# For bin 7 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [109 183 203 948]
#
# For bin 8 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 80  64 294 479]
#
# For bin 9 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [213  76 248  83]
#
# For bin 10 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [120 289]
#
# For bin 11 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 63 505]
#
# The weighted average (by frequency) of this bin is:
# [6.33108788718207, 8.256229615133725, 8.422735951991271, 6.75977312390925, 4.865057264765327, 5.788438617401669, 6.583583333333333, 7.726749826749828, 7.393238822246456, 4.526774193548388, 8.050366748166258, 8.889788732394365]
# 6.966152009735162
# 7.5
# For bin 0 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [130  46 365 153]
#
# For bin 1 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 58 218  99 527]
#
# For bin 2 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  5 101  14 753]
#
# For bin 3 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 47  65  50 693]
#
# For bin 4 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [264 118 165 518]
#
# For bin 5 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [296  64 208 495]
#
# For bin 6 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [176 123 313 467]
#
# For bin 7 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 32  72  46 872]
#
# For bin 8 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  5  19 138 501]
#
# For bin 9 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [111  12 149  16]
#
# For bin 10 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 39 160]
#
# The weighted average (by frequency) of this bin is:
# [5.914265129682997, 7.387472283813747, 8.770675830469644, 8.375672514619882, 6.1418779342723, 5.977234242709313, 6.559128822984245, 8.660078277886498, 8.63529411764706, 4.1885416666666675, 8.498492462311559]
# 7.191703025733083
# RMSE = 3.8812111876447593
# MAE = 3.710461103128705

# %%
df_scaled = scale_df(df.copy())
df_scaled['y'] = df['y']
selected_features = ['wind speed', 'pitch angle', 'rotor speed']
models_file = 'trained_models_all.pickle' 
with open(models_file, 'rb') as file:
    models_dict = pickle.load(file)
    
bin_feature = 'wind speed'
binned_data_dfs = []
for b in bin_masks:
    df_temp = df_scaled[b]
    binned_data_dfs.append(df_temp.copy())
    
fit_features = ['wind speed', 'pitch angle', 'rotor speed', 'nacelle direction', 'wind direction', 'theta_d']
target_feature = ['active power']
    
evaluation_scores = {}
evaluation_preds = {}
static_misalignment_values1 = [x for i, x in enumerate(static_misalignment_values) if i != 4]
print(static_misalignment_values1)
for theta_s in tqdm(np.unique(static_misalignment_values1)):
    #print(f'Working on {theta_s}')
    evaluation_scores[str(theta_s)] = {}
    evaluation_preds[str(theta_s)] = {}
    for key, models in models_dict.items():
        mape_list = []
        evaluation_preds[str(theta_s)][key] = {}
        #print(f'evaluating with models trained on {key}')
        for bin_n, d in enumerate(binned_data_dfs):
            d = d[d['y'] == theta_s].copy()
            if d.shape[0] >= 100 and models[bin_n] is not None:
                test_preds = predict(d, models[bin_n], fit_features, target_feature)
                r_sq, mae, me, mape, mpe = score(d[target_feature].values, test_preds)
                mape_list.append(mae)
                evaluation_preds[str(theta_s)][key][str(bin_n)] = test_preds
            else:
                evaluation_preds[str(theta_s)][key][str(bin_n)] = None
        avg_mape = np.mean(mape_list)
        evaluation_scores[str(theta_s)][key] = avg_mape
print(evaluation_scores)

# estimate the angle using a weighted average with the frequency of each point
result = {}
for th_s in np.unique(static_misalignment_values1): 
    print(th_s)
    average_for_each_bin = []
    for bin_n, d in enumerate(binned_data_dfs):
        d = d[d['y'] == th_s].copy()
        if d.shape[0] <= 100 or test_preds is None:
            continue
            
        # label each point in one bin to the closest prediction by the models of each angle of the bin
        label_per_bin = np.zeros(d[target_feature].shape) - 1
        diffs_per_bin = np.zeros(d[target_feature].shape) + np.inf # used to hold the minimum diffs until now
        l_test = np.zeros(d[target_feature].shape) - 1
        scoring_metrics = {}
        test_diffs = []
        for key, bin_dict in evaluation_preds[str(th_s)].items():
            # these are the predictions if the trained model corresponding to "key" angle/ in bin bin_n
            test_preds = bin_dict[str(bin_n)]
            if d.shape[0] >= 100 and test_preds is not None:
                # calculate the differences between the actual and predicted values (residuals)
                (r_sq, mae, me, mape, mpe) = score(d[target_feature].values, test_preds)
                temp_diff = np.abs(test_preds-d[target_feature].values)
                test_diffs.append(temp_diff.ravel())
#                 # unncomment line below for histograms of the differences for each bin for each model
#                 plt.hist(temp_diff, label=key, bins = 20)
#                 plt.axvline(temp_diff.mean(), color='k', linestyle='dashed', linewidth=1, label=f'mean of {key} = {temp_diff.mean():.3}')
#                 plt.legend()
#                 plt.show()
                mask = (temp_diff <= diffs_per_bin) # mask to find the points with current difference lower than the minimum
                diffs_per_bin[mask] = temp_diff[mask]
                scoring_metrics[str(np.abs(float(key)))] = (r_sq, mae, me, mape, mpe) # store metrics 
                label_per_bin[mask] = np.abs(float(key)) # assign labels
            else:
                pass
        unique, counts = np.unique(label_per_bin, return_counts=True)
        print(f"For bin {bin_n} in the regions with ground truth angle {th_s}")
        print(f"The distribution of prediction labels for the interval is:")
        print(unique, counts, end='\n\n')
        # barplot  with the frequencies of each label
#         plt.bar(np.arange(unique.shape[0]), counts)
#         plt.xticks(np.arange(unique.shape[0]), labels=unique)
#         plt.show()
        # calculate weighted average for each bin
        if n_most_freq is not None:
            idx = np.argmax(counts)
            unique = unique[idx]
            counts = counts[idx]
        res = np.average(unique, weights=counts)
        average_for_each_bin.append(res)
    print("The weighted average (by frequency) of this bin is:")
    print(average_for_each_bin)
    print(np.mean(average_for_each_bin))
    result[str(th_s)] = np.mean(average_for_each_bin)
    
df['y_pred'] = np.nan
for th_s in np.unique(static_misalignment_values1): 
    df['y_pred'][df['y']==th_s] = result[str(th_s)]

prediction = np.abs(df['y_pred'])
target = np.abs(df['y'])

rmse = np.sqrt(np.nanmean((prediction.values-target.values)**2))
mae = np.nanmean(np.abs(prediction.values-target.values))
m = (prediction.isna())
print(f"RMSE = {rmse}")
print(f"MAE = {mae}")

target.plot(figsize=(12, 8), label = 'Measured static yaw')
prediction.plot(alpha=0.5, label = 'Predicted static yaw')
plt.title('All features')
plt.legend()
plt.show()
# Out:
# [-2.2, 3.4, 7.5, 0, 0]
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'-2.2': {'-6.7': 0.03196907290841682, '0.0': 0.0772419385227578, '4.8': 0.0346383560972723, '9.4': 0.08062249085223941}, '0.0': {'-6.7': 0.08552847064771534, '0.0': 0.04456281471673335, '4.8': 0.06246356284866865, '9.4': 0.08751954918890578}, '3.4': {'-6.7': 0.02923289899192334, '0.0': 0.08560385018636951, '4.8': 0.03927072143618628, '9.4': 0.041306279173294734}, '7.5': {'-6.7': 0.027738149681419928, '0.0': 0.10704624512189534, '4.8': 0.036591046547749036, '9.4': 0.034449624182341994}}
# -2.2
# For bin 0 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 605 2239 3239 1250]
#
# For bin 1 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 226 2455 1258 2816]
#
# For bin 2 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 181 1451  573 3851]
#
# For bin 3 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 389 1493 1086 1708]
#
# For bin 4 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 954  929 1126  459]
#
# For bin 5 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [496 701 679 464]
#
# For bin 6 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [137 547 410 354]
#
# For bin 7 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 45 300 339 178]
#
# For bin 8 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 60 106 138  75]
#
# For bin 9 in the regions with ground truth angle -2.2
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [25 27 78  9]
#
# The weighted average (by frequency) of this bin is:
# [6.027342151915996, 6.910880829015544, 7.761443196829591, 6.522198460222413, 4.705305651672433, 5.246025641025641, 6.008425414364641, 6.246519721577727, 5.64221635883905, 5.300719424460432]
# 6.037107684992347
# 0.0
# For bin 0 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1538  713  439  950]
#
# For bin 1 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1273  658  233 1105]
#
# For bin 2 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1726  408  514  198]
#
# For bin 3 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1650  212  274  370]
#
# For bin 4 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1212  283  420  101]
#
# For bin 5 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [788 182 142 228]
#
# For bin 6 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [568 184  95 195]
#
# For bin 7 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [293 276  27  62]
#
# For bin 8 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [94 71 46 51]
#
# For bin 9 in the regions with ground truth angle 0.0
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [60 43  4 28]
#
# The weighted average (by frequency) of this bin is:
# [4.201565934065934, 4.621137962679718, 2.5521433591004916, 2.5264964086193133, 2.5405753968253966, 2.9613432835820896, 3.2175623800383875, 3.1740121580547114, 4.306870229007634, 3.677037037037037]
# 3.377874414901072
# 3.4
# For bin 0 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 436 2255 3442 1809]
#
# For bin 1 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 181 1730 1443 4311]
#
# For bin 2 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 148 1257  547 5380]
#
# For bin 3 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 498 1655 1278 2299]
#
# For bin 4 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [1138 1009 1211 1095]
#
# For bin 5 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [859 698 803 996]
#
# For bin 6 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [218 561 783 838]
#
# For bin 7 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 20 419 632 372]
#
# For bin 8 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 25 166 513 213]
#
# For bin 9 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 55  91 360 114]
#
# For bin 10 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [172 237]
#
# For bin 11 in the regions with ground truth angle 3.4
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 32 536]
#
# The weighted average (by frequency) of this bin is:
# [6.407705867539662, 7.631506849315069, 8.220199127114022, 6.652216404886562, 5.221176734785538, 5.391209773539929, 6.590041666666667, 6.751489951489953, 6.800545256270446, 6.323225806451614, 7.465525672371639, 9.140845070422538]
# 6.882974015071137
# 7.5
# For bin 0 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 23 127 449  95]
#
# For bin 1 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  4 233 285 380]
#
# For bin 2 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [4.8 6.7 9.4] [228  65 580]
#
# For bin 3 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 17 432 104 302]
#
# For bin 4 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [131 152 395 387]
#
# For bin 5 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [176 269 381 237]
#
# For bin 6 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 37 207 448 387]
#
# For bin 7 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  2 335 528 157]
#
# For bin 8 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [  3  27 482 151]
#
# For bin 9 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [0.  4.8 6.7 9.4] [ 17   6 133 132]
#
# For bin 10 in the regions with ground truth angle 7.5
# The distribution of prediction labels for the interval is:
# [4.8 9.4] [ 36 163]
#
# The weighted average (by frequency) of this bin is:
# [6.499855907780979, 7.316962305986696, 7.997594501718213, 6.560467836257311, 6.5858215962441315, 5.711853245531516, 7.074142724745134, 6.478864970645793, 7.207239819004524, 7.502430555555555, 8.5678391959799]
# 7.045733878131796
# RMSE = 3.4397465110754406
# MAE = 3.3213710475388836
